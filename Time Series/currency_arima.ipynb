# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
currency = pd.read_excel(r'C:\Users\hp\Documents\Time Series\Currency.xlsx')

# %%
currency.head()
# Out:
#            Date  Price   Open   High    Low Volume    Chg%
# 0  Mar 08, 2023  82.12  82.21  82.38  82.08  2.96M  0.0011
# 1  Mar 06, 2023  82.03  81.95  82.07  81.71  3.35M -0.0006
# 2  Mar 03, 2023  82.07  82.55  82.60  82.02  3.95M -0.0076
# 3  Mar 02, 2023  82.71  82.60  82.72  82.60  1.38M  0.0011
# 4  Mar 01, 2023  82.61  82.64  82.75  82.49  2.45M -0.0012

# %%
type(currency)
# Out:
# pandas.core.frame.DataFrame

# %%
type(currency['Date'])
# Out:
# pandas.core.series.Series

# %%
currency.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1968 entries, 0 to 1967
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1968 non-null   object
#  1   Price   1968 non-null   float64
#  2   Open    1968 non-null   float64
#  3   High    1968 non-null   float64
#  4   Low     1968 non-null   float64
#  5   Volume  1968 non-null   object
#  6   Chg%    1968 non-null   float64
# dtypes: float64(5), object(2)
# memory usage: 107.8+ KB

# %%
from statsmodels.tsa.arima_process import arma_generate_sample

# %%
curr = pd.read_excel(r'C:\Users\hp\Documents\Time Series\Currency.xlsx', index_col='Date', parse_dates=True)

# %%
curr.head()
# Out:
#             Price   Open   High    Low Volume    Chg%
# Date
# 2023-03-08  82.12  82.21  82.38  82.08  2.96M  0.0011
# 2023-03-06  82.03  81.95  82.07  81.71  3.35M -0.0006
# 2023-03-03  82.07  82.55  82.60  82.02  3.95M -0.0076
# 2023-03-02  82.71  82.60  82.72  82.60  1.38M  0.0011
# 2023-03-01  82.61  82.64  82.75  82.49  2.45M -0.0012

# %%
curr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1968 entries, 2023-03-08 to 2015-01-30
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   1968 non-null   float64
#  1   Open    1968 non-null   float64
#  2   High    1968 non-null   float64
#  3   Low     1968 non-null   float64
#  4   Volume  1968 non-null   object
#  5   Chg%    1968 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.6+ KB

# %%
type(curr)
# Out:
# pandas.core.frame.DataFrame

# %%
from statsmodels.tsa.stattools import adfuller

# %%
curr_train = curr.loc[:'2022']
curr_test = curr.loc['2023':]
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10956\1648584573.py:2: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   curr_test = curr.loc['2023':]

# %%
curr_test.head()
# Out:
#             Price   Open   High    Low Volume    Chg%
# Date
# 2023-03-08  82.12  82.21  82.38  82.08  2.96M  0.0011
# 2023-03-06  82.03  81.95  82.07  81.71  3.35M -0.0006
# 2023-03-03  82.07  82.55  82.60  82.02  3.95M -0.0076
# 2023-03-02  82.71  82.60  82.72  82.60  1.38M  0.0011
# 2023-03-01  82.61  82.64  82.75  82.49  2.45M -0.0012

# %%
curr_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 46 entries, 2023-03-08 to 2023-01-02
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   46 non-null     float64
#  1   Open    46 non-null     float64
#  2   High    46 non-null     float64
#  3   Low     46 non-null     float64
#  4   Volume  46 non-null     object
#  5   Chg%    46 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 2.5+ KB

# %%
curr_test.tail()
# Out:
#             Price   Open   High    Low Volume    Chg%
# Date
# 2023-01-06  82.78  82.62  82.85  82.55  2.98M  0.0026
# 2023-01-05  82.56  82.89  82.90  82.52  2.87M -0.0044
# 2023-01-04  82.92  83.05  83.05  82.82  2.37M -0.0023
# 2023-01-03  83.12  82.87  83.17  82.78  2.73M  0.0023
# 2023-01-02  82.93  83.14  83.14  82.67  1.84M  0.0011

# %%
curr['Price']
# Out:
# Date
# 2023-03-08    82.12
# 2023-03-06    82.03
# 2023-03-03    82.07
# 2023-03-02    82.71
# 2023-03-01    82.61
#               ...
# 2015-02-05    61.97
# 2015-02-04    62.04
# 2015-02-03    61.99
# 2015-02-02    62.12
# 2015-01-30    62.23
# Name: Price, Length: 1968, dtype: float64

# %%
curr['Price'].head()
# Out:
# Date
# 2023-03-08    82.12
# 2023-03-06    82.03
# 2023-03-03    82.07
# 2023-03-02    82.71
# 2023-03-01    82.61
# Name: Price, dtype: float64

# %%
curr = curr.drop('Chg%', axis=1)

# %%
curr.head()
# Out:
#             Price   Open   High    Low Volume
# Date
# 2023-03-08  82.12  82.21  82.38  82.08  2.96M
# 2023-03-06  82.03  81.95  82.07  81.71  3.35M
# 2023-03-03  82.07  82.55  82.60  82.02  3.95M
# 2023-03-02  82.71  82.60  82.72  82.60  1.38M
# 2023-03-01  82.61  82.64  82.75  82.49  2.45M

# %%
curr.drop(['Open', 'High', 'Low', 'Volume'], axis=1, inplace=True)

# %%
curr.head()
# Out:
#             Price
# Date
# 2023-03-08  82.12
# 2023-03-06  82.03
# 2023-03-03  82.07
# 2023-03-02  82.71
# 2023-03-01  82.61

# %%
curr = curr.resample('D').ffill().reset_index()

# %%
curr.head()
# Out:
#         Date  Price
# 0 2015-01-30  62.23
# 1 2015-01-31  62.23
# 2 2015-02-01  62.23
# 3 2015-02-02  62.12
# 4 2015-02-03  61.99

# %%
curr.tail()
# Out:
#            Date  Price
# 2955 2023-03-04  82.07
# 2956 2023-03-05  82.07
# 2957 2023-03-06  82.03
# 2958 2023-03-07  82.03
# 2959 2023-03-08  82.12

# %%
type(curr)
# Out:
# pandas.core.frame.DataFrame

# %%
curr.set_index('Date', inplace=True)

# %%
curr.head()
# Out:
#             Price
# Date
# 2015-01-30  62.23
# 2015-01-31  62.23
# 2015-02-01  62.23
# 2015-02-02  62.12
# 2015-02-03  61.99

# %%
curr_train = curr.loc[:'2022']
curr_test = curr.loc['2023':]

# %%
curr_test.head()
# Out:
#             Price
# Date
# 2023-01-01  82.84
# 2023-01-02  82.93
# 2023-01-03  83.12
# 2023-01-04  82.92
# 2023-01-05  82.56

# %%
curr_train.head()
# Out:
#             Price
# Date
# 2015-01-30  62.23
# 2015-01-31  62.23
# 2015-02-01  62.23
# 2015-02-02  62.12
# 2015-02-03  61.99

# %%
curr_train.tail()
# Out:
#             Price
# Date
# 2015-02-05  61.97
# 2015-02-04  62.04
# 2015-02-03  61.99
# 2015-02-02  62.12
# 2015-01-30  62.23

# %%
fig, ax = plt.subplots()
curr.plot(ax=ax)
plt.show()

# %%
fig, ax1 = plt.subplots()
curr_train.plot(ax=ax1)
curr_test.plot(ax=ax1)
plt.show()

# %%
result = adfuller(curr['Price'])
print(result)
# Out:
# (-1.6436111387343748, 0.4603744972866012, 4, 1963, {'1%': -3.4336856453443994, '5%': -2.863013493272342, '10%': -2.5675544273932758}, 11.856890766998276)

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
from pandas.plotting import autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import statsmodels.api as sm

# %%
curr_diff = curr.diff().dropna()
curr_diff.head()
# Out:
#             Price
# Date
# 2015-01-31   0.00
# 2015-02-01   0.00
# 2015-02-02  -0.11
# 2015-02-03  -0.13
# 2015-02-04   0.05

# %%
curr_train_diff = curr_diff.loc[:'2022']
curr_test_diff = curr_diff.loc['2023':]

# %%
curr_train_diff.head()
# Out:
#             Price
# Date
# 2015-01-31   0.00
# 2015-02-01   0.00
# 2015-02-02  -0.11
# 2015-02-03  -0.13
# 2015-02-04   0.05

# %%
curr_test_diff.head()
# Out:
#             Price
# Date
# 2023-01-01   0.00
# 2023-01-02   0.09
# 2023-01-03   0.19
# 2023-01-04  -0.20
# 2023-01-05  -0.36

# %%
result_diff = adfuller(curr_diff)
print(result_diff)
# Out:
# (-21.517545270773372, 0.0, 3, 1963, {'1%': -3.4336856453443994, '5%': -2.863013493272342, '10%': -2.5675544273932758}, 12.960846637894065)

# %%
fig, ax2 = plt.subplots()
curr_diff.plot(ax=ax2)
plt.show()

# %%
autocorrelation_plot(curr)
plt.show()

# %%
autocorrelation_plot(curr_train)
plt.show()

# %%
autocorrelation_plot(curr_diff)
plt.show()

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(curr_diff,lags=20,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(curr_diff,lags=20,ax=ax2)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# !pip install pmdarima
# Out:
# ...
#      -------------------------------------- 572.7/572.7 kB 1.7 MB/s eta 0:00:00
# ...

# %%
from pmdarima.arima import auto_arima
model_autoARIMA = auto_arima(curr_train.diff().dropna(), start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=5, max_q=5, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
model_autoARIMA.plot_diagnostics(figsize=(15,8))
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=19.357, Time=0.23 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=18.886, Time=0.24 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=18.665, Time=0.18 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=19.442, Time=0.38 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=17.912, Time=0.23 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=19.911, Time=0.52 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=19.909, Time=0.30 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=16.138, Time=0.83 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=8.029, Time=2.15 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=6.017, Time=1.93 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=19.541, Time=0.46 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=17.555, Time=1.77 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=19.669, Time=0.95 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=9.852, Time=2.39 sec
# ...

# %%
type(model_autoARIMA)
# Out:
# pmdarima.arima.arima.ARIMA

# %%
model = ARIMA(curr_train_diff['Price'], order=(2,0,2))
model_fit = model.fit()
print(model_fit.summary())
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\hp\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\hp\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\hp\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
model = ARIMA(curr_train['Price'], order=(2,1,2))
model_fit = model.fit()
print(model_fit.summary())
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\hp\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\hp\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\hp\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
from statsmodels.graphics.tsaplots import plot_predict
fig, axs = plt.subplots()
curr.plot(ax=axs)
plot_predict(model_fit, start=len(curr_train), end=(len(curr)-1), ax=axs)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
